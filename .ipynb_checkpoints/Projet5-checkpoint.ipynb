# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from Functions_Vincent import *
from sklearn import preprocessing

pd.options.display.max_columns = 50
pd.options.display.max_rows = 100
pd.set_option('display.width', 1000)

#Types de couleurs utilisées pour les comparaisons de grade
colors=["limegreen","gold", "darkorange", "red","steelblue","purple","black","grey","pink"]

from matplotlib import style
#style.use('dark_background')
style.use('default')

# %%
# Regardons le nom des colonne, le type de variable et leurs taux de valeurs utilisables
Df_category_name = pd.read_csv('product_category_name_translation.csv').drop_duplicates()
print('Df_category_name')
print(Df_category_name.columns.values)
info_data_unique(Df_category_name)
print(' ')

Df_sellers = pd.read_csv('olist_sellers_dataset.csv').drop_duplicates()
print('Df_sellers')
print(Df_sellers.columns.values)
info_data_unique(Df_sellers)

print(' ')

Df_products = pd.read_csv('olist_products_dataset.csv').drop_duplicates()
print('Df_products')

print(Df_products.columns.values)
info_data_unique(Df_products)

print(' ')

Df_orders = pd.read_csv('olist_orders_dataset.csv').drop_duplicates()
print('Df_orders')

print(Df_orders.columns.values)
info_data_unique(Df_orders)

print(' ')

Df_order_reviews = pd.read_csv('olist_order_reviews_dataset.csv').drop_duplicates()
print('Df_order_reviews')

print(Df_order_reviews.columns.values)
info_data_unique(Df_order_reviews)

print(' ')

Df_payements = pd.read_csv('olist_order_payments_dataset.csv').drop_duplicates()
print('Df_payements')

print(Df_payements.columns.values)
info_data_unique(Df_payements)

print(' ')

Df_order_items = pd.read_csv('olist_order_items_dataset.csv').drop_duplicates()
print('Df_order_items')

print(Df_order_items.columns.values)
info_data_unique(Df_order_items)

print(' ')

Df_geo = pd.read_csv('olist_geolocation_dataset.csv').drop_duplicates()
print('Df_geo')

print(Df_geo.columns.values)
info_data_unique(Df_geo)
print(' ')


Df_customers = pd.read_csv('olist_customers_dataset.csv').drop_duplicates()
print('Df_customers')

print(Df_customers.columns.values)
info_data_unique(Df_customers)
# Out:
# Df_category_name
# ['product_category_name' 'product_category_name_english']
# les colonnes sont de types :   [dtype('O')]
#
# il y a : 71 lignes, 2 colonnes
#
# il y a : 100.0 % de valeurs utilisables
#
# Df_sellers
# ['seller_id' 'seller_zip_code_prefix' 'seller_city' 'seller_state']
# les colonnes sont de types :   [dtype('O') dtype('int64')]
#
# il y a : 3095 lignes, 4 colonnes
#
# il y a : 100.0 % de valeurs utilisables
#
# Df_products
# ['product_id' 'product_category_name' 'product_name_lenght'
#  'product_description_lenght' 'product_photos_qty' 'product_weight_g'
#  'product_length_cm' 'product_height_cm' 'product_width_cm']
# les colonnes sont de types :   [dtype('O') dtype('float64')]
#
# il y a : 32951 lignes, 9 colonnes
#
# il y a : 99.2 % de valeurs utilisables
#
# Df_orders
# ['order_id' 'customer_id' 'order_status' 'order_purchase_timestamp'
#  'order_approved_at' 'order_delivered_carrier_date'
#  'order_delivered_customer_date' 'order_estimated_delivery_date']
# ...

# %%
#Pltons les Df qui ne sont pas à 100% de valeurs utilisables

print("Df_products")
plot_valeurs_utilisables(Df_products)
print("Df_orders")
plot_valeurs_utilisables(Df_orders)
print("Df_order_reviews")
plot_valeurs_utilisables(Df_order_reviews)
# Out:
# Df_products
# Df_orders
# Df_order_reviews

# %%
#Df_order_reviews=Df_order_reviews.drop(['review_comment_title','review_comment_message'],axis=1)

# %%
#créons une liste avec toutes les colonnes des Df pour vérifier s'il ya des doublons
Liste_cols_multi_Df = []

for col in Df_category_name.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_sellers.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_orders.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_order_reviews.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_payements.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_order_items.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_geo.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_customers.columns:
    Liste_cols_multi_Df.append(col)

for col in Df_products.columns:
    Liste_cols_multi_Df.append(col)

# %%
#customer_id,order_id,seller_id et product_category_name sont en doublons

Liste_cols_multi_Df = pd.Series(Liste_cols_multi_Df)
Liste_cols_multi_Df[Liste_cols_multi_Df.duplicated(keep='last')].drop_duplicates()
# Out:
# 0     product_category_name
# 2                 seller_id
# 6                  order_id
# 7               customer_id
# 28               product_id
# dtype: object

# %%
Liste_cols = ['customer_id','order_id', 'order_status', 'order_item_id', 'product_id', 'price', 'freight_value', 
 'review_id', 'review_score',  'review_creation_date']

# %%
Df= pd.merge(Df_orders,Df_order_items)
Df = pd.merge(Df,Df_order_reviews)
Df= Df[Liste_cols]

# %%
#créons un seul Df qui regroupe tous les autres Dfs
Df_orders.head(5)
Df_customers.head(5)
Df_customers_orders = pd.merge(Df_customers,Df_orders)

#On a plus besoin de Df_orders ni de Df_customers puisqu'on les a rassemblé en Df_customers_orders

# %%
Df_full_info_orders = pd.merge(Df_customers_orders,Df_order_items)
Df_full_info_orders = pd.merge(Df_full_info_orders,Df_payements)
Df_full_info_orders = pd.merge(Df_full_info_orders,Df_order_reviews)
Df_full_info_orders = pd.merge(Df_full_info_orders,Df_sellers)
Df_product_and_categories = pd.merge(Df_category_name,Df_products)
Df_full_info_orders = pd.merge(Df_full_info_orders,Df_product_and_categories)

# %%
#Il reste Df_geo, pas sur qu'il soit utile
print(Df_geo.columns.values,'\n')
print(Df_full_info_orders.columns.values)
# Out:
# ['geolocation_zip_code_prefix' 'geolocation_lat' 'geolocation_lng'
#  'geolocation_city' 'geolocation_state']
#
# ['customer_id' 'customer_unique_id' 'customer_zip_code_prefix'
#  'customer_city' 'customer_state' 'order_id' 'order_status'
#  'order_purchase_timestamp' 'order_approved_at'
#  'order_delivered_carrier_date' 'order_delivered_customer_date'
#  'order_estimated_delivery_date' 'order_item_id' 'product_id' 'seller_id'
#  'shipping_limit_date' 'price' 'freight_value' 'payment_sequential'
#  'payment_type' 'payment_installments' 'payment_value' 'review_id'
#  'review_score' 'review_comment_title' 'review_comment_message'
#  'review_creation_date' 'review_answer_timestamp' 'seller_zip_code_prefix'
#  'seller_city' 'seller_state' 'product_category_name'
#  'product_category_name_english' 'product_name_lenght'
#  'product_description_lenght' 'product_photos_qty' 'product_weight_g'
#  'product_length_cm' 'product_height_cm' 'product_width_cm']

# %%
Df_full_info_orders
# Out:
#                              customer_id                customer_unique_id  customer_zip_code_prefix    customer_city customer_state                          order_id order_status order_purchase_timestamp    order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date  order_item_id                        product_id                         seller_id  shipping_limit_date   price  freight_value  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score review_comment_title                             review_comment_message review_creation_date review_answer_timestamp  seller_zip_code_prefix           seller_city seller_state product_category_name product_category_name_english  product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm
# ...

# %%
plot_valeurs_utilisables(Df_full_info_orders)

# %%
#Vérifions les types des varaibles
Df_full_info_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    115609 non-null  object
#  1   customer_unique_id             115609 non-null  object
#  2   customer_zip_code_prefix       115609 non-null  int64
#  3   customer_city                  115609 non-null  object
#  4   customer_state                 115609 non-null  object
#  5   order_id                       115609 non-null  object
#  6   order_status                   115609 non-null  object
#  7   order_purchase_timestamp       115609 non-null  object
#  8   order_approved_at              115595 non-null  object
#  9   order_delivered_carrier_date   114414 non-null  object
#  10  order_delivered_customer_date  113209 non-null  object
#  11  order_estimated_delivery_date  115609 non-null  object
# ...

# %%
#Remplaçons les dates par des types dates
col_to_date = Df_full_info_orders.columns[Df_full_info_orders.columns.str.contains('date')]

for col in col_to_date :
    Df_full_info_orders=time_to_datetime(Df_full_info_orders,col)
    
Df_full_info_orders=time_to_datetime(Df_full_info_orders,'order_purchase_timestamp')
Df_full_info_orders=time_to_datetime(Df_full_info_orders,'order_approved_at')
Df_full_info_orders=time_to_datetime(Df_full_info_orders,'review_answer_timestamp')

# %%
#Liste de colonnes de type datetime
cols_datetime = Df_full_info_orders.columns[Df_full_info_orders.dtypes=='datetime64[ns]']

# %%
#Info sur les colonnes de type non datetime
Df_full_info_orders[Df_full_info_orders.columns[~Df_full_info_orders.columns.isin(cols_datetime)]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    115609 non-null  object
#  1   customer_unique_id             115609 non-null  object
#  2   customer_zip_code_prefix       115609 non-null  int64
#  3   customer_city                  115609 non-null  object
#  4   customer_state                 115609 non-null  object
#  5   order_id                       115609 non-null  object
#  6   order_status                   115609 non-null  object
#  7   order_item_id                  115609 non-null  int64
#  8   product_id                     115609 non-null  object
#  9   seller_id                      115609 non-null  object
#  10  price                          115609 non-null  float64
#  11  freight_value                  115609 non-null  float64
# ...

# %%
#Remplaçons les autres colonnes par des string
Df_full_info_orders=object_to_string(Df_full_info_orders)

# %%
List_to_drop = ["product_length_cm","product_width_cm","product_height_cm","seller_zip_code_prefix",
                "product_category_name","seller_city","seller_state","seller_id","review_comment_title",
                "review_creation_date","customer_zip_code_prefix","customer_city","customer_state",
                "order_status","order_delivered_carrier_date",'order_purchase_timestamp', 'order_approved_at', 
                 'order_delivered_customer_date', 'order_estimated_delivery_date', 
                 'shipping_limit_date']
Df_full_info_orders.drop(List_to_drop,axis=1,inplace=True)


Df_full_info_orders=Df_full_info_orders[['customer_id', 'customer_unique_id', 'order_id',  'order_item_id', 'product_id', 'price', 'freight_value', 'payment_sequential', 'payment_type', 'payment_installments', 
 'payment_value', 'review_id', 'review_score', 'review_comment_message', 'review_answer_timestamp',
 'product_category_name_english', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty',
 'product_weight_g']]

# %%
#Creons la liste des customer qui ont passé plusieurs commandes
"""Liste_duplicated_customer = Df_full_info_orders.customer_id[Df_full_info_orders.order_item_id>1].drop_duplicates()
Liste_duplicated_customer 

Df_full_info_orders = Df_full_info_orders[Df_full_info_orders.customer_id.isin(Liste_duplicated_customer)]"""
# Out:
# 'Liste_duplicated_customer = Df_full_info_orders.customer_id[Df_full_info_orders.order_item_id>1].drop_duplicates()\nListe_duplicated_customer \n\nDf_full_info_orders = Df_full_info_orders[Df_full_info_orders.customer_id.isin(Liste_duplicated_customer)]'

# %%
Df_full_info_orders.groupby(by=["customer_id"]).sum().sort_values(by='order_item_id',ascending=False)
# Out:
#                                   order_item_id    price  freight_value  payment_sequential  payment_installments  payment_value  review_score  product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g
# customer_id
# fc3d1daec319d62d49bfb5e1f83123e9            231    31.80         164.37                  21                    42        4118.31            21                927.0                      4782.0                62.0           17000.0
# be1b70680b9f9694d8c70f41fa3dc92b            210  2000.00         202.40                  20                    20       44048.00            20                860.0                      9040.0                20.0            7200.0
# be1c4e52bb71e0c54b11a26b8e8d59f2            132  1430.16         277.72                  22                    66       18786.90            22                730.0                      4954.0                30.0           26800.0
# ...

# %%
ll=Df.customer_id[Df.order_item_id>10]
Df[Df.customer_id.isin(ll)].sort_values(by="customer_id")
# Out:
#                              customer_id                          order_id order_status  order_item_id                        product_id  price  freight_value                         review_id  review_score review_creation_date
# 19233   0d93f21f3e8543a9d0d8ece01561f5b2  2c2a19b5703863c908512d135aa6accc    delivered             12  03e1c946c0ddfc58724ff262aef08dff   20.7          16.11  fede3915bdef46df7b0101af03518b71             5  2017-10-19 00:00:00
# 19222   0d93f21f3e8543a9d0d8ece01561f5b2  2c2a19b5703863c908512d135aa6accc    delivered              1  03e1c946c0ddfc58724ff262aef08dff   20.7          16.11  fede3915bdef46df7b0101af03518b71             5  2017-10-19 00:00:00
# 19223   0d93f21f3e8543a9d0d8ece01561f5b2  2c2a19b5703863c908512d135aa6accc    delivered              2  03e1c946c0ddfc58724ff262aef08dff   20.7          16.11  fede3915bdef46df7b0101af03518b71             5  2017-10-19 00:00:00
# ...

# %%
Df_full_info_orders[Df_full_info_orders.customer_id=='0d93f21f3e8543a9d0d8ece01561f5b2']
# Out:
#                             customer_id                customer_unique_id                          order_id  order_item_id                        product_id  price  freight_value  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score review_comment_message review_answer_timestamp product_category_name_english  product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g
# 25124  0d93f21f3e8543a9d0d8ece01561f5b2  ce9f8b9c31d83341764708396ac7e38b  2c2a19b5703863c908512d135aa6accc              1  03e1c946c0ddfc58724ff262aef08dff   20.7          16.11                   1       boleto                     1         441.72  fede3915bdef46df7b0101af03518b71             5                   <NA>     2017-10-19 22:55:25                    housewares                 46.0                       465.0                 1.0             550.0
# ...

# %%
for col in  Df_full_info_orders.columns:
    print(col, 'possède', round(Df_full_info_orders[col].nunique()/len(Df_full_info_orders)*100,2),"% de valeurs uniques")
# Out:
# customer_id possède 83.48 % de valeurs uniques
# customer_unique_id possède 80.79 % de valeurs uniques
# order_id possède 83.48 % de valeurs uniques
# order_item_id possède 0.02 % de valeurs uniques
# product_id possède 27.83 % de valeurs uniques
# price possède 5.09 % de valeurs uniques
# freight_value possède 6.02 % de valeurs uniques
# payment_sequential possède 0.03 % de valeurs uniques
# payment_type possède 0.0 % de valeurs uniques
# payment_installments possède 0.02 % de valeurs uniques
# payment_value possède 24.79 % de valeurs uniques
# review_id possède 83.31 % de valeurs uniques
# review_score possède 0.0 % de valeurs uniques
# review_comment_message possède 30.43 % de valeurs uniques
# review_answer_timestamp possède 83.18 % de valeurs uniques
# product_category_name_english possède 0.06 % de valeurs uniques
# product_name_lenght possède 0.06 % de valeurs uniques
# product_description_lenght possède 2.56 % de valeurs uniques
# ...

# %%
plot_valeurs_utilisables(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15156/3518173213.py in <module>
# ----> 1 plot_valeurs_utilisables(data)
#
# NameError: name 'data' is not defined

# %%
data = Df_full_info_orders.dropna()
Df=Df.dropna()
info_data_unique(Df)

# %%
cols_to_encode = Df.columns[(Df.dtypes=='datetime64[ns]')|(Df.dtypes=='string')|(Df.dtypes=='O')]

laben = preprocessing.LabelEncoder()

#encodons les valeurs non numériques
for encode in cols_to_encode :
    Df[encode] = laben.fit_transform(Df[encode])
Df.shape

# %%
X = Df.values
X.shape

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %%
from sklearn import decomposition
n_comp = X.shape[1]
print(n_comp)
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)

# %%
print(pca.explained_variance_ratio_.cumsum())

# %%
plt.plot(list(range(1,n_comp+1)),pca.explained_variance_ratio_.cumsum())
plt.title('inertie par features')
plt.show()

# %%
# 1. Choisissons le clustering avec kmeans 
from sklearn import cluster
myclust = cluster.KMeans(n_clusters=2)
myclust.fit(X)

# %%
# 2. Visualisation
# On commence par réduire la dimension des données avec tSNE. On scale d’abord les données :
from sklearn import preprocessing
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %%
# Puis on applique tSNE aux données scalées :
from sklearn import manifold
tsne = manifold.TSNE(n_components=2, init='pca')
X_trans = tsne.fit_transform(X_scaled)

# %%
y= data.review_score.values

# %%
# Puis on visualise, selon la méthode donnée dans le coup de pouce :
from matplotlib import pyplot as plt # Dans Jupyter : % pylab inline
plt.figure(figsize=(15,15))
for i in range(X.shape[0]): # pour chaque point
    plt.text(X_trans[i, 0], X_trans[i, 1], str('%s' % y[i]),
            color=plt.cm.Set2(myclust.labels_[i]/10.))
    
# On redéfinit les axes pour bien voir tous les points
plt.xlim([np.min(X_trans[:, 0]), np.max(X_trans[:, 0])])
plt.ylim([np.min(X_trans[:, 1]), np.max(X_trans[:, 1])])

# On affiche l'image
plt.show()

# %%
# projeter X sur les composantes principales
X_projected = pca.transform(X_scaled)

# afficher chaque observation
plt.scatter(X_projected[:, 0], X_projected[:, 1],
    # colorer en utilisant la variable 'Rank'
    c=data.get('review_score'))

plt.xlim([-5.5, 5.5])
plt.ylim([-4, 4])
plt.colorbar()
